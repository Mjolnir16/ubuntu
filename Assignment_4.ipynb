# %%
import pandas as pd

# %%
df = pd.read_csv('Titanic.csv')
df
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  Parch  Pclass  Embarked  \
# 0               1  22.0    7.2500    0      1      0       3       2.0
# 1               2  38.0   71.2833    1      1      0       1       0.0
# 2               3  26.0    7.9250    1      0      0       3       2.0
# 3               4  35.0   53.1000    1      1      0       1       2.0
# 4               5  35.0    8.0500    0      0      0       3       2.0
# ...           ...   ...       ...  ...    ...    ...     ...       ...
# 1304         1305  28.0    8.0500    0      0      0       3       2.0
# 1305         1306  39.0  108.9000    1      0      0       1       0.0
# 1306         1307  38.5    7.2500    0      0      0       3       2.0
# 1307         1308  28.0    8.0500    0      0      0       3       2.0
# 1308         1309  28.0   22.3583    0      1      1       3       0.0
#
#       Survived
# 0            0
# 1            1
# 2            1
# 3            1
# 4            0
# ...        ...
# ...

# %% [markdown]
#  # More than 1000 people have ticket price less than 50 & very few people have luxury seat prices

# %%
import matplotlib
import numpy as np
df.hist(column='Fare')
# Out:
# array([[<Axes: title={'center': 'Fare'}>]], dtype=object)

# %% [markdown]
# # Most people on titanic were of the age 28

# %%
import seaborn as sns
df = pd.read_csv("Titanic.csv")
sns.histplot(data = df, x = "Age", stat = "count", discrete = True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# # There were more males than females on The TITANIC

# %%
sns.histplot(data = df, x = "Sex", stat = "count", discrete = True)
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %% [markdown]
# # More people died than survived during TITANIC tragedy

# %%
sns.histplot(data = df, x = "Survived", stat = "count", discrete = True)
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %% [markdown]
# # The fare was zero for infants

# %%
gp = df.groupby("Age")
gp.groups.keys()
sns.histplot(data = df, x = "Age", y = "Fare", discrete = True)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
df = pd.read_csv("Titanic.csv")
sns.boxplot(x = df["Age"], y = df["Fare"], hue = df["Survived"])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>
